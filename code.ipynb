# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Raw data
data = [
    1.816232546, 1.95208107, 2.056758721, 2.149996692, 2.051663016, 
    1.973685114, 1.914979549, 1.711499794, 1.889696499, 1.999051378, 
    1.93974116, 1.963619551, 1.796990762, 1.894855924, 1.862227252, 
    2.251728545, 2.077257909, 1.911476929, 1.938653886, 2.135830145, 
    2.293800622, 1.887975299, 1.865039361, 2.048745193, 1.968015445, 
    2.120824579, 1.822388896, 1.994449942, 2.18584339, 2.252021006, 
    2.137092334, 1.966955701, 2.089696282, 1.993713432, 1.555931645, 
    1.8463313, 1.89984826, 1.865694331, 1.985387697, 2.07903646, 
    2.195418503, 1.81928222, 2.050370545, 2.257618061, 1.976497548, 
    2.126577958, 1.801947396, 1.756783202, 1.991568885, 1.807348985, 
    1.591711728, 1.430770471, 1.704509882, 1.927005433, 1.943955383, 
    1.879364281, 1.81700965, 1.674536277, 1.833950127, 1.726292517, 
    1.92785237, 2.080642071, 1.803172426, 2.10200506, 1.93718073, 
    1.909524727, 1.742255801, 1.613615176, 2.164813868, 1.526914631, 
    1.756850514, 2.070374308, 2.067424627, 2.109754914, 1.833216462, 
    1.766421148, 2.071906978, 2.055978423, 1.758128571, 1.645528733, 
    2.182677051, 2.232902698, 1.950092818, 2.08965174, 1.694780398, 
    1.810553418, 1.622583134, 1.948096329, 1.733301977, 2.047905724, 
    1.774996418, 1.818802164, 1.830685267, 2.082727387, 1.837806191, 
    1.600843082, 1.914891138, 1.899435302, 1.91449909, 2.123947542, 
    2.00448494, 1.882976435, 1.719419932, 1.752341003, 1.9819114, 
    2.103779213, 2.220083531, 1.826378264, 2.020882441, 1.75585937, 
    2.105150711, 1.98844268, 1.895607341, 1.924236973, 1.531480695, 
    1.814322988, 1.811776126, 1.884847485, 1.322590159, 1.915643854, 
    2.102056387, 1.992477436, 1.951248731, 1.753597129, 1.897603368, 
    1.939861895, 2.032089156, 1.450381218, 2.277686684, 1.963434272, 
    1.816630928, 2.084936417, 2.08227627, 1.553572075, 1.898017082, 
    2.179323075, 1.857589344, 1.97905613, 2.145895025, 2.002340441, 
    1.622563395, 1.804193512, 2.021138208, 2.052144854, 2.089985756, 
    1.628714911, 1.83433832, 1.921819427, 1.92721214, 1.747542831, 
    1.960115911, 1.762138398, 2.021624382, 2.064251759, 1.690387286, 
    2.018424812, 1.904842589, 1.804794147, 1.741237807, 1.833075742, 
    1.713069735, 1.797602366, 2.039032222, 2.238439028, 1.970276576, 
    2.021887903, 2.075232697, 1.833823892, 1.825854891, 2.011922583, 
    1.788942171, 2.124753043, 2.026488977, 1.441390789, 1.867500631, 
    2.107432368, 2.25229866, 1.81151471, 1.855392893, 1.874768542, 
    2.078222048, 1.651464301, 1.810548511, 1.563153107, 1.882183489, 
    1.900293943, 1.642197412, 1.756408592, 2.059579338, 1.59567159, 
    1.761494401, 1.703787631, 1.76273051, 1.920684645, 1.969690848, 
    1.975124925, 1.812762356, 1.242155479, 2.12947498, 1.824741209
]


# Create histogram with 10 bins
plt.figure(figsize=(10, 6))
plt.hist(data, bins=10, alpha=0.7, color='blue', edgecolor='black')

# Add a line overlay (mean line, for example)
mean_value = np.mean(data)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1)

# Customize labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Service Time Placing Keyboard & Mouse')

# Show plot
plt.grid(True)
plt.show()

# %%
interarrival_times = [
    3.91435, 3.97431, 1.51432, 1.49221, 0.326715, 2.65771, 4.12484, 10.4102, 0.207232, 0.5371, 
    2.82784, 0.994121, 2.03849, 1.3022, 3.39366, 0.755393, 3.42662, 0.313983, 13.6793, 13.9936, 
    8.13392, 3.30456, 7.83843, 6.90589, 0.190783, 2.23693, 12.7586, 18.4756, 1.14974, 7.86326, 
    6.71879, 5.71631, 0.823182, 10.7208, 11.6697, 4.26399, 1.22935, 6.67564, 2.727, 1.50164, 3.11805, 
    12.4161, 5.20551, 0.375493, 0.180925, 1.08324, 3.21349, 9.18804, 12.0057, 0.640511, 5.67734, 
    5.96325, 1.84295, 12.6313, 0.502292, 3.30672, 21.6263, 21.5059, 3.09548, 0.30261, 3.71099, 
    0.604309, 6.51969, 4.98825, 0.0886604, 0.937201, 11.5294, 3.38196, 3.11396, 2.49927, 0.920183, 
    2.78742, 5.30708, 25.7196, 4.83757, 1.67911, 1.18747, 2.22537, 11.2992, 3.50348, 5.99338, 
    0.507637, 3.42981, 2.33437, 3.13644, 7.26151, 25.8213, 2.2908, 17.9109, 15.6572, 6.46786, 
    2.00442, 9.91392, 4.68517, 14.1407, 0.0201689, 4.42416, 4.89306, 17.6625, 5.82983, 12.988, 
    1.91691, 11.2846, 13.7037, 3.13843, 3.54983, 17.5532, 3.44286, 0.333378, 17.7745, 1.65263, 
    5.78283, 6.82052, 2.05715, 11.2458, 0.635802, 2.14907, 4.66315, 7.68127, 1.96991, 6.01382, 
    2.16329, 2.59673, 0.793283, 36.7632, 14.9785, 3.37599, 2.16509, 0.540465, 1.99577, 4.43422, 
    2.7344, 7.52799, 7.40058, 3.06512, 0.157485, 18.0006, 0.527298, 2.94953, 5.82032, 2.30145, 
    5.84049, 0.237069, 2.72374, 1.41385, 1.76092, 4.76304, 4.43347, 3.48908, 2.93912, 7.90686, 
    11.2433, 1.15597, 0.610297, 4.26761, 1.18413, 15.5012, 3.24748, 3.58907, 2.28689, 3.42668, 
    0.271564, 1.10473, 3.18492, 3.55022, 34.9602, 2.41416, 5.04943, 1.999, 0.180464, 0.431582, 
    1.61077, 1.86042, 1.7447, 7.76353, 18.7743, 6.695, 1.83602, 1.53388, 11.1453, 7.98852, 
    2.34035, 3.57066, 4.38115, 0.734442, 5.15855, 2.06164, 0.984308, 0.99653, 0.942869, 0.273439, 
    1.44881, 2.81526, 3.26198, 5.60619, 7.34839, 2.72353, 1.62717, 15.9017, 0.453735
]


# Create histogram with 10 bins
plt.figure(figsize=(10, 6))
plt.hist(interarrival_times, bins=10, alpha=0.7, color='blue', edgecolor='black')

# Add a line overlay (mean line, for example)
mean_value = np.mean(interarrival_times)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1)

# Customize labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Interarrival Times')

# Show plot
plt.grid(True)
plt.show()

# %%
# Data for service time assembling case
service_time_assembling_case = [
    7.15378, 5.41364, 3.62873, 5.57592, 3.80641, 5.24363, 4.52913, 5.10526, 1.66592, 5.97763, 
    6.5052, 4.04747, 4.25636, 4.09336, 4.39756, 4.07151, 4.96926, 4.61753, 2.75999, 6.14684, 
    5.53991, 3.72112, 1.4198, 5.44827, 6.66547, 7.00465, 5.73299, 5.1342, 5.8672, 3.38612, 3.64895, 
    6.26626, 2.99326, 2.19315, 5.82251, 3.08662, 4.09376, 3.75617, 4.44842, 5.02087, 7.02961, 
    4.88888, 4.12125, 6.29073, 4.17204, 3.46268, 4.02891, 5.93955, 3.67547, 5.27223, 6.96566, 
    6.55864, 3.58819, 3.99307, 5.95576, 6.85704, 4.28831, 5.55066, 4.71689, 3.50596, 6.91692, 
    6.97345, 4.75112, 4.39559, 7.56973, 2.59893, 9.04656, 6.35961, 5.29419, 3.9157, 7.37476, 
    3.96958, 5.98344, 4.36141, 4.65016, 4.9639, 2.42706, 2.14829, 5.92369, 4.28899, 5.6194, 
    2.83752, 5.1172, 1.5798, 3.44912, 1.92663, 4.4184, 4.81089, 5.59782, 4.03341, 4.99875, 
    7.88326, 5.55617, 2.84434, 7.33476, 3.27252, 6.17544, 9.66713, 4.97413, 3.94728, 5.83798, 
    5.70171, 6.36668, 3.65527, 2.87635, 2.91518, 6.48689, 4.34772, 4.21466, 7.64946, 3.91132, 
    9.7968, 1.21148, 5.1422, 4.56543, 4.84804, 4.31981, 6.63256, 3.50979, 2.26176, 5.19304, 
    4.44533, 1.71011, 3.61011, 6.72814, 6.84468, 5.5187, 6.26154, 2.45599, 5.13303, 6.11769, 
    6.37346, 5.86377, 5.20643, 2.13188, 3.17256, 6.05993, 2.42315, 5.20067, 4.47554, 3.37809, 
    4.20528, 5.27635, 4.72867, 4.35268, 3.63692, 7.76213, 2.90738, 1.65315, 6.70883, 3.52596, 
    5.27129, 5.09957, 5.39871, 7.60636, 3.37814, 3.466, 4.28025, 6.47837, 3.47511, 3.51276, 
    6.01254, 4.52862, 6.15892, 5.64143, 4.32807, 3.44885, 5.3777, 3.6443, 1.88582, 6.21941, 
    1.76238, 3.6819, 3.99888, 3.67024, 8.60475, 9.01083, 4.74625, 1.57551, 3.88802, 4.15947, 
    4.39761, 3.42368, 3.74124, 6.1655, 3.08906, 6.70464, 4.39544, 5.76019, 5.81029, 4.44802, 
    6.08239, 5.65738, 3.40342, 0.92095, 4.25719, 3.06142, 3.10967, 3.62528, 4.79398
]

# Create histogram with 10 bins
plt.figure(figsize=(10, 6))
plt.hist(service_time_assembling_case, bins=10, alpha=0.7, color='blue', edgecolor='black')

# Add a line overlay (mean line, for example)
mean_value = np.mean(service_time_assembling_case)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1)

# Customize labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Service Time Assembling Case')

# Show plot
plt.grid(True)
plt.show()

# %%
service_time_initial_phase = [
    7.15378, 5.41364, 3.62873, 5.57592, 3.80641, 5.24363, 4.52913, 5.10526, 1.66592, 5.97763, 
    6.5052, 4.04747, 4.25636, 4.09336, 4.39756, 4.07151, 4.96926, 4.61753, 2.75999, 6.14684, 
    5.53991, 3.72112, 1.4198, 5.44827, 6.66547, 7.00465, 5.73299, 5.1342, 5.8672, 3.38612, 3.64895, 
    6.26626, 2.99326, 2.19315, 5.82251, 3.08662, 4.09376, 3.75617, 4.44842, 5.02087, 7.02961, 
    4.88888, 4.12125, 6.29073, 4.17204, 3.46268, 4.02891, 5.93955, 3.67547, 5.27223, 6.96566, 
    6.55864, 3.58819, 3.99307, 5.95576, 6.85704, 4.28831, 5.55066, 4.71689, 3.50596, 6.91692, 
    6.97345, 4.75112, 4.39559, 7.56973, 2.59893, 9.04656, 6.35961, 5.29419, 3.9157, 7.37476, 
    3.96958, 5.98344, 4.36141, 4.65016, 4.9639, 2.42706, 2.14829, 5.92369, 4.28899, 5.6194, 
    2.83752, 5.1172, 1.5798, 3.44912, 1.92663, 4.4184, 4.81089, 5.59782, 4.03341, 4.99875, 
    7.88326, 5.55617, 2.84434, 7.33476, 3.27252, 6.17544, 9.66713, 4.97413, 3.94728, 5.83798, 
    5.70171, 6.36668, 3.65527, 2.87635, 2.91518, 6.48689, 4.34772, 4.21466, 7.64946, 3.91132, 
    9.7968, 1.21148, 5.1422, 4.56543, 4.84804, 4.31981, 6.63256, 3.50979, 2.26176, 5.19304, 
    4.44533, 1.71011, 3.61011, 6.72814, 6.84468, 5.5187, 6.26154, 2.45599, 5.13303, 6.11769, 
    6.37346, 5.86377, 5.20643, 2.13188, 3.17256, 6.05993, 2.42315, 5.20067, 4.47554, 3.37809, 
    4.20528, 5.27635, 4.72867, 4.35268, 3.63692, 7.76213, 2.90738, 1.65315, 6.70883, 3.52596, 
    5.27129, 5.09957, 5.39871, 7.60636, 3.37814, 3.466, 4.28025, 6.47837, 3.47511, 3.51276, 
    6.01254, 4.52862, 6.15892, 5.64143, 4.32807, 3.44885, 5.3777, 3.6443, 1.88582, 6.21941, 
    1.76238, 3.6819, 3.99888, 3.67024, 8.60475, 9.01083, 4.74625, 1.57551, 3.88802, 4.15947, 
    4.39761, 3.42368, 3.74124, 6.1655, 3.08906, 6.70464, 4.39544, 5.76019, 5.81029, 4.44802, 
    6.08239, 5.65738, 3.40342, 0.92095, 4.25719, 3.06142, 3.10967, 3.62528, 4.79398
]

# Create histogram with 10 bins
plt.figure(figsize=(10, 6))
plt.hist(service_time_initial_phase, bins=10, alpha=0.7, color='blue', edgecolor='black')

# Add a line overlay (mean line, for example)
mean_value = np.mean(service_time_initial_phase)
plt.axvline(mean_value, color='red', linestyle='dashed', linewidth=1)

# Customize labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Service Time Initial Phase')

# Show plot
plt.grid(True)
plt.show()

# %%
initialy_ACT = [
    1847.889515, 2410.575732, 2456.303123, 2421.43735, 2388.737615, 2392.655879, 2537.040447, 
    2418.897963, 2348.411194, 2517.696778, 2414.760646, 2419.456543, 2389.890045, 2396.002995, 
    2552.551236, 2420.049606, 2333.372871, 2543.459791, 2396.955028, 2413.34818, 2398.014343, 
    2390.748039, 2589.413663, 2337.388082, 2360.567153, 2530.64268, 2389.449601, 2424.584088, 
    2393.394266, 2413.357149, 2556.831884, 2314.298599, 2396.227109, 2535.317333, 2389.814827, 
    2420.958571, 2393.602154, 2450.591428, 2477.748292, 2350.282833, 2393.824845, 2547.093908, 
    2381.435811, 2415.602452, 2425.817722, 2441.099799, 2423.11624
]

# %%
ext1_ACT = [
    1357.234752, 1261.060285, 1264.381675, 1294.3374, 1281.641975, 1282.11293, 1253.511455, 
    1291.01143, 1283.422564, 1275.713593, 1270.646195, 1289.536595, 1270.549422, 1286.745397, 
    1256.230929, 1290.233411, 1261.133479, 1305.64611, 1252.001776, 1284.900943, 1288.524467, 
    1277.254387, 1263.636055, 1267.170882, 1287.208645, 1280.982855, 1278.402856, 1265.03188, 
    1274.267256, 1281.958684, 1278.832505, 1263.113043, 1280.387309, 1293.747354, 1277.695881, 
    1259.291846, 1267.122734, 1280.591455, 1285.192398, 1286.746361, 1258.808034, 1290.080016, 
    1273.682131, 1280.733708, 1239.760532, 1279.346662, 1273.370456
]

# %%
ext2_ACT = [
    1091.400995, 1253.241476, 1238.057418, 1237.998962, 1238.855791, 1247.224699, 1247.796324, 
    1252.088685, 1228.891425, 1237.550213, 1238.749603, 1246.864763, 1243.305707, 1243.853053, 
    1244.810177, 1236.391185, 1237.919143, 1242.334465, 1236.850805, 1236.106476, 1250.561518, 
    1259.886839, 1245.029737, 1251.132917, 1258.049003, 1242.262645, 1239.553384, 1241.828123, 
    1251.93015, 1234.08348, 1239.662524, 1252.282099, 1250.150418, 1243.247434, 1240.624609, 
    1246.828101, 1221.565115, 1235.249243, 1239.409826, 1241.472519, 1244.665001, 1240.398419, 
    1260.145669, 1244.925195, 1235.342801, 1249.118998, 1238.460849
]

# %%
# Plotting the data
plt.figure(figsize=(10, 6))

# Plotting each dataset with different line styles and labels
plt.plot(initialy_ACT, label='Initial ACT', linestyle='-', marker='o')
plt.plot(ext1_ACT, label='Recommendation 1 ACT', linestyle='--', marker='x')
plt.plot(ext2_ACT, label='Recommendation 1 ACT', linestyle=':', marker='s')

# Adding title and labels
plt.title('Trends of ACT')
plt.xlabel('Replication')
plt.ylabel('ACT Value')

# Adding a legend to differentiate the lines
plt.legend()

# Displaying the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
initial_hard_disk = [
    322.212911, 240.5573769, 159.7280724, 196.4475123, 145.8212836, 177.6454873, 238.0250492, 
    177.1211264, 169.3203984, 246.9925085, 148.7279229, 212.1046633, 138.6153781, 184.7074116, 
    270.3876004, 128.2996568, 180.1595758, 229.1515078, 155.9856393, 214.8453208, 140.7407559, 
    184.1062629, 256.516956, 122.947368, 196.7008509, 216.0184102, 164.5544984, 212.7009661, 
    137.7820604, 241.625623, 193.7862301, 132.9811304, 183.644525, 226.9075179, 165.9276276, 
    196.1966579, 148.7283725, 231.0115722, 184.6034931, 143.4414018, 176.0471017, 238.4792651, 
    188.9215358, 161.6975307, 244.7043681, 152.0215434, 200.3469827
]

# %%
recommendation_1_hard_disk = [
    71.78691473, 70.05644772, 70.93497034, 59.43856971, 48.53173323, 68.84377743, 69.79496351, 
    68.33357481, 69.07809725, 68.09149968, 68.14553982, 67.04289079, 69.88156022, 74.0606219, 
    69.86292116, 74.04581606, 69.30507443, 70.08012769, 67.34646995, 69.51396987, 70.99757587, 
    68.69937408, 69.27820593, 68.41711267, 73.06038667, 67.10187742, 72.25317083, 69.45127441, 
    71.22129564, 67.87305253, 70.64297648, 66.74222668, 71.14718382, 72.19471442, 70.47284585, 
    72.44079308, 71.50663045, 71.55548755, 68.07366015, 71.64540019, 70.82249628, 70.48544397, 
    72.52588558, 68.40985759, 70.54532487, 71.10940001, 67.9531256
]

# %%
recommendation_2_hard_disk = [
    93.56396832, 163.5710149, 80.2860497, 114.9393323, 53.25509675, 85.18983637, 139.5264051, 
    77.3671101, 115.9843526, 52.70305717, 92.33410316, 139.1242306, 77.8822673, 114.5647679, 
    53.4786384, 87.72167076, 148.1477439, 79.03739307, 109.9035468, 53.12083372, 89.56481558, 
    132.6151376, 92.38604984, 146.3916119, 58.90088935, 51.68685378, 116.6217683, 91.47835399, 
    145.909281, 78.84136885, 111.2360484, 48.47082372, 90.23346428, 149.9774518, 82.82495741, 
    108.604011, 50.7830594, 85.9809045, 148.3818019, 81.71971189, 115.2219861, 53.22291822, 
    86.42732557, 136.5316631, 78.22558811, 112.3801573, 47.49986919
]

# %%
# Plotting the data
plt.figure(figsize=(10, 6))

# Plotting each dataset with different line styles and labels
plt.plot(initial_hard_disk, label='Initial Hard Disk', linestyle='-', marker='o')
plt.plot(recommendation_1_hard_disk, label='Recommendation 1 Hard Disk', linestyle='--', marker='x')
plt.plot(recommendation_2_hard_disk, label='Recommendation 2 Hard Disk', linestyle=':', marker='s')

# Adding title and labels
plt.title('Trends of Hard Disk Data')
plt.xlabel('Replication')
plt.ylabel('Average Queue Waiting Times (Minutes)')

# Adding a legend to differentiate the lines
plt.legend()

# Displaying the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
initial_manufacturing_plates = [
    1100.560642, 1958.031085, 1921.128174, 1849.455727, 1939.235916, 1895.726879, 1949.968337, 
    1893.601985, 1834.503265, 1972.810391, 1915.042644, 1852.742476, 1955.137868, 1879.694008, 
    1959.888629, 1867.644171, 1870.470424, 1987.493741, 1898.48897, 1845.188777, 1932.959172, 
    1891.110999, 1938.214903, 1886.61967, 1858.061496, 1981.644703, 1887.611087, 1887.461187, 
    1905.206864, 1890.101487, 1894.439918, 1926.021966, 1896.886853, 1968.246696, 1895.057262, 
    1852.118031, 1957.334192, 1910.801297, 1881.370799, 1929.718925, 1902.883291, 1944.128741, 
    1914.370768, 1813.973649, 1952.371843, 1928.001145, 1847.563512
]

# %%
recommendation_1_manufacturing_plates = [
    213.1454884, 205.9941239, 192.4435315, 187.2929974, 207.4577232, 198.6388028, 178.4265225, 
    189.9459912, 211.3474798, 198.2909066, 178.0959214, 169.4442295, 203.3626864, 219.0479023, 
    188.311089, 165.8474403, 196.7893139, 222.0575826, 204.7178748, 146.9972556, 203.0937313, 
    200.1708121, 222.7578297, 180.8595853, 170.5727909, 218.3624057, 210.731668, 188.7610304, 
    178.341769, 183.9900314, 231.9428104, 203.3169547, 163.8295009, 201.1136738, 207.5712987, 
    223.3458894, 174.5137293, 190.2968339, 212.3605297, 201.3021376, 200.0594672, 176.9646589, 
    200.846519, 208.8460273, 199.3203146, 172.9715667, 203.5332165
]

# %%
recommendation_2_manufacturing_plates = [
    921.4499347, 980.9933778, 223.6009443, 217.0186761, 201.4520194, 217.8948393, 205.0262725, 
    222.1166702, 222.9060927, 219.0769149, 195.5866688, 194.7108626, 218.4578633, 216.4882218, 
    211.0945765, 214.5756524, 212.2961156, 207.4182531, 209.3621356, 219.6660794, 226.8889738, 
    211.3844419, 208.1981584, 189.8166649, 198.3974872, 223.6003611, 220.3990842, 225.7336461, 
    192.5236659, 196.4695707, 231.4377934, 209.8530921, 222.6097759, 224.3675879, 217.4373837, 
    179.6074894, 243.4173864, 219.8534925, 233.5796092, 224.1443883, 219.651369, 193.4732311, 
    187.7949819, 201.1004868, 233.7688646, 213.3219362, 219.6571264
]

# %%
# Plotting the data
plt.figure(figsize=(10, 6))

# Plotting each dataset with different line styles and labels
plt.plot(initial_manufacturing_plates, label='Initial Manufacturing Plates', linestyle='-', marker='o')
plt.plot(recommendation_1_manufacturing_plates, label='Recommendation 1 Manufacturing Plates', linestyle='--', marker='x')
plt.plot(recommendation_2_manufacturing_plates, label='Recommendation 2 Manufacturing Plates', linestyle=':', marker='s')

# Adding title and labels
plt.title('Trends of Manufacturing Plates')
plt.xlabel('Replication')
plt.ylabel('Average Queue Waiting Times (Minutes)')

# Adding a legend to differentiate the lines
plt.legend()

# Displaying the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
initial_cutting_keyboard = [
    16528.00644, 24450.95214, 12812.72609, 29201.76406, 12221.52481, 15153.63024, 25559.03763, 
    13034.19014, 29124.41215, 8334.279394, 28490.2785, 25425.91299, 25424.54718, 28646.53727, 
    12398.09935, 28812.4691, 26546.12136, 12818.83848, 30067.39098, 24868.42665, 29355.84272, 
    26333.85803, 25135.18521, 28778.27349, 23827.49447, 29239.97697, 27195.2051, 25543.41045, 
    30370.17829, 23885.64969, 27402.09489, 28078.46708, 12522.70862, 15050.55122, 24293.39346, 
    27752.9791, 28165.76606, 12321.18133, 29172.8194, 23765.34846, 13977.88884, 27761.26416, 
    12329.57575, 31074.82163, 24131.7359, 26385.10496, 28621.32876
]

# %%
recommendation_1_cutting_keyboard = [
    105216.8425, 72090.9816, 226445.263, 227517.2193, 228483.5219, 76451.90865, 223831.9646, 
    222082.2565, 73188.15304, 118907.6206, 121154.3104, 230709.845, 105361.4937, 219375.6784, 
    231356.1728, 225399.7, 108581.3307, 111363.4449, 114712.523, 120902.9089, 106852.1629, 
    107046.1003, 70349.63388, 236687.6883, 109613.9757, 104250.1159, 218383.3362, 231377.4929, 
    224518.7383, 216599.4846, 108755.9033, 77197.82152, 118908.0286, 212055.5801, 74542.31078, 
    211198.8006, 113633.8961, 234165.1799, 111340.7923, 116168.7276, 112523.2425, 112754.3184, 
    107186.5712, 105071.4967, 217767.5162, 111813.0312, 207949.8698
]

# %%
recommendation_2_cutting_keyboard_rework = [
    0.217432116, 0.282365733, 0.017380409, 0.226724181, 0.261084728, 0.133054511, 0.136419099, 
    0.124390758, 0.279613586, 0.166180799, 0.025672476, 0.410133637, 0.169674285, 0.035450346, 
    0.090820932, 0.227847347, 0.173236466, 0.04724951, 0.215809759, 0.15276159, 0.07961719, 
    0.211383457, 0.181708757, 0.097976923, 0.104264488, 0.234274102, 0.076335923, 0.027774826, 
    0.376669178, 0.100662538, 0.381896182, 0.237204806, 0.191572726, 0.128628207, 0.102748124, 
    0.083692411, 0.100016466, 0.003270555, 0.128753504, 0.016082602, 0.193754092, 0.039046129, 
    0.074634148, 0.079930125, 0.038246834, 0, 0.286732908
]

# %%
import matplotlib.pyplot as plt

# Plotting the data
plt.figure(figsize=(10, 6))

# Plotting each dataset with different line styles and labels
plt.plot(initial_cutting_keyboard, label='Initial Cutting Keyboard & Mouse', linestyle='-', marker='o')
plt.plot(recommendation_1_cutting_keyboard, label='Recommendation 1 Cutting Keyboard & Mouse', linestyle='--', marker='x')
plt.plot(recommendation_2_cutting_keyboard_rework, label='Recommendation 2 Cutting Keyboard & Mouse (Rework)', linestyle=':', marker='s')

# Adding title and labels
plt.title('Trends of Cutting Keyboard & Mouse')
plt.xlabel('Replications')
plt.ylabel('Average Queue Waiting Times (Minutes)')

# Adding a legend to differentiate the lines
plt.legend()

# Displaying the plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Function to calculate statistical measures: Mean, SE, CI
def calc_stats(data, confidence_level=0.99):
    mean_val = np.mean(data)
    std_dev = np.std(data, ddof=1)  # Using ddof=1 to calculate sample standard deviation
    n = len(data)
    se = std_dev / np.sqrt(n)
    
    # Confidence interval for given confidence level (99% in this case)
    t_value = stats.t.ppf((1 + confidence_level) / 2, df=n-1)  # t-statistic for given confidence level
    ci = t_value * se
    
    return mean_val, se, ci

# Dataset: initialy_ACT, ext1_ACT, ext2_ACT
datasets = {
    "Initial ACT": initialy_ACT,
    "Recommendation 1 ACT": ext1_ACT,
    "Recommendation 2 ACT": ext2_ACT
}

# Plot each dataset in its own figure
for label, data in datasets.items():
    mean_val, se, ci = calc_stats(data)
    
    # Create a new figure for each dataset
    plt.figure(figsize=(10, 6))
    
    # Plot the dataset
    plt.plot(data, label=f'{label} Data', color='blue', linestyle='-', marker='o', markersize=4)
    
    # Plot the mean
    plt.axhline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
    
    # Plot the confidence intervals in a different color (green)
    plt.fill_between(range(len(data)), mean_val - ci, mean_val + ci, color='green', alpha=0.3, label=f'99% CI')
    
    # Add title and labels
    plt.title(f'{label}', fontsize=14)
    plt.xlabel('Replication')
    plt.ylabel('ACT Value (Minutes)')
    plt.legend()
    plt.grid(True)
    
    # Display the plot
    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt

# Data: Average Queue Waiting Times for each stage
stages = [
    "Hard Disk", "Initial Phase", "Main Assembly", "Manufacturing Plate", 
    "Place Keyboard", "Place Motherboard", "Place Screen", "Power Assembly", 
    "Quality", "Shaping Screen", "Boxing", "Assembling Case", "Cutting Keyboard"
]

# Corresponding average waiting times for each stage
avg_waiting_times = [
    191.0637662, 6.507424295, 3.279819688, 1889.810523, 0, 20.80497387, 
    0.795279615, 0.060875602, 127.5480771, 0, 0, 0.039404302, 23242.367
]

# Create a bar plot to visualize the average waiting times for each stage
plt.figure(figsize=(10, 6))

# Bar plot
bars = plt.bar(stages, avg_waiting_times, color='blue', edgecolor='black')

# Annotating the bars with the average waiting times
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() + 10,
             f'{bar.get_height():.2f}', ha='center', fontsize=10)

# Add title and labels
plt.title('Average Queue Waiting Times for Each Activity', fontsize=16)
plt.xlabel('Activities', fontsize=12)
plt.ylabel('Average Waiting Time (Minutes)', fontsize=12)

# Rotate x-axis labels to make them readable
plt.xticks(rotation=45, ha='right')

# Show the plot
plt.tight_layout()
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data: Resource Utilization for 3 models (initial, recommendation 1, and recommendation 2)
resources = ['Type 1 Worker', 'Type 2 Worker', 'Type 3 Worker', 'Type 4 Worker', 'Type 5 Worker', 'Roll & Cut Machine', 'Special Machine', 'Workbench']

# Values for initial, recommendation 1, and recommendation 2
initial = [
    0.555126389, 0.363088195, 0.514168789, 0.520704695, 0.246370267, 
    0.325607973, 0.514168789, 0.391411504
]
recommendation_1 = [
    0.877056714, 0.611917114, 0.957105684, 0.974696754, 0.461918553, 
    0.615023271, 0.957105684, 0.69579823
]
recommendation_2 = [
    0.889814924, 0.636203791, 0.837266273, 0.977730596, 0.475745762, 
    0.632065519, 0.837266273, 0.646661543
]

# Set the width of the bars
bar_width = 0.25

# Define the position of the bars on the x-axis
x = np.arange(len(resources))

# Create a grouped bar chart
fig, ax = plt.subplots(figsize=(12, 6))

# Plot the bars for each model in groups
ax.bar(x - bar_width, initial, bar_width, label='Initial', color='blue')
ax.bar(x, recommendation_1, bar_width, label='Recommendation 1', color='orange')
ax.bar(x + bar_width, recommendation_2, bar_width, label='Recommendation 2', color='pink')

# Add titles and labels
ax.set_title('Resource Utilisation for Different Models', fontsize=16)
ax.set_xlabel('Resources', fontsize=12)
ax.set_ylabel('Average Utilisation', fontsize=12)

# Set the x-axis ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(resources, rotation=45, ha='right')

# Add a legend
ax.legend()

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Data for the 47 replications for each queue
cutting_keyboard = [
    16528.00644, 24450.95214, 12812.72609, 29201.76406, 12221.52481, 15153.63024, 25559.03763, 
    13034.19014, 29124.41215, 8334.279394, 28490.2785, 25425.91299, 25424.54718, 28646.53727, 
    12398.09935, 28812.4691, 26546.12136, 12818.83848, 30067.39098, 24868.42665, 29355.84272, 
    26333.85803, 25135.18521, 28778.27349, 23827.49447, 29239.97697, 27195.2051, 25543.41045, 
    30370.17829, 23885.64969, 27402.09489, 28078.46708, 12522.70862, 15050.55122, 24293.39346, 
    27752.9791, 28165.76606, 12321.18133, 29172.8194, 23765.34846, 13977.88884, 27761.26416, 
    12329.57575, 31074.82163, 24131.7359, 26385.10496, 28621.32876
]

manufacturing_plates = [
    1100.560642, 1958.031085, 1921.128174, 1849.455727, 1939.235916, 1895.726879, 1949.968337, 
    1893.601985, 1834.503265, 1972.810391, 1915.042644, 1852.742476, 1955.137868, 1879.694008, 
    1959.888629, 1867.644171, 1870.470424, 1987.493741, 1898.48897, 1845.188777, 1932.959172, 
    1891.110999, 1938.214903, 1886.61967, 1858.061496, 1981.644703, 1887.611087, 1887.461187, 
    1905.206864, 1890.101487, 1894.439918, 1926.021966, 1896.886853, 1968.246696, 1895.057262, 
    1852.118031, 1957.334192, 1910.801297, 1881.370799, 1929.718925, 1902.883291, 1944.128741, 
    1914.370768, 1813.973649, 1952.371843, 1928.001145, 1847.563512
]

hard_disk = [
    322.212911, 240.5573769, 159.7280724, 196.4475123, 145.8212836, 177.6454873, 238.0250492, 
    177.1211264, 169.3203984, 246.9925085, 148.7279229, 212.1046633, 138.6153781, 184.7074116, 
    270.3876004, 128.2996568, 180.1595758, 229.1515078, 155.9856393, 214.8453208, 140.7407559, 
    184.1062629, 256.516956, 122.947368, 196.7008509, 216.0184102, 164.5544984, 212.7009661, 
    137.7820604, 241.625623, 193.7862301, 132.9811304, 183.644525, 226.9075179, 165.9276276, 
    196.1966579, 148.7283725, 231.0115722, 184.6034931, 143.4414018, 176.0471017, 238.4792651, 
    188.9215358, 161.6975307, 244.7043681, 152.0215434, 200.3469827
]

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# Function to calculate the mean, standard error (SE), and confidence interval (CI)
def calc_ci(data, confidence_level=0.99):
    mean_val = np.mean(data)
    std_dev = np.std(data, ddof=1)  # Sample standard deviation
    n = len(data)
    se = std_dev / np.sqrt(n)  # Standard error

    # Calculate the t value for the given confidence level
    t_value = stats.t.ppf((1 + confidence_level) / 2, df=n-1)
    
    # Confidence interval
    ci = t_value * se
    return mean_val, ci

# For Cutting Keyboard
mean_ck, ci_ck = calc_ci(cutting_keyboard)

# Create a figure for Cutting Keyboard
plt.figure(figsize=(10, 6))
plt.plot(cutting_keyboard, label='Cutting Keyboard', color='blue', linestyle='-', marker='o')
plt.axhline(mean_ck, color='red', linestyle='--', label=f'Mean: {mean_ck:.2f}')
plt.fill_between(range(len(cutting_keyboard)), mean_ck - ci_ck, mean_ck + ci_ck, color='blue', alpha=0.2, label=f'99% CI')
plt.title('Cutting Keyboard & Mouse - Average Queue Waiting Times', fontsize=14)
plt.xlabel('Replication', fontsize=12)
plt.ylabel('Average Waiting Time (Minutes)', fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# For Manufacturing Plates
mean_mp, ci_mp = calc_ci(manufacturing_plates)

# Create a figure for Manufacturing Plates
plt.figure(figsize=(10, 6))
plt.plot(manufacturing_plates, label='Manufacturing Plates', color='green', linestyle='-', marker='o')
plt.axhline(mean_mp, color='red', linestyle='--', label=f'Mean: {mean_mp:.2f}')
plt.fill_between(range(len(manufacturing_plates)), mean_mp - ci_mp, mean_mp + ci_mp, color='green', alpha=0.2, label=f'99% CI')
plt.title('Manufacturing Plates - Average Queue Waiting Times', fontsize=14)
plt.xlabel('Replication', fontsize=12)
plt.ylabel('Average Waiting Time (Minutes)', fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# For Hard Disk
mean_hd, ci_hd = calc_ci(hard_disk)

# Create a figure for Hard Disk
plt.figure(figsize=(10, 6))
plt.plot(hard_disk, label='Hard Disk', color='red', linestyle='-', marker='o')
plt.axhline(mean_hd, color='red', linestyle='--', label=f'Mean: {mean_hd:.2f}')
plt.fill_between(range(len(hard_disk)), mean_hd - ci_hd, mean_hd + ci_hd, color='red', alpha=0.2, label=f'99% CI')
plt.title('Hard Disk - Average Queue Waiting Times', fontsize=14)
plt.xlabel('Replication', fontsize=12)
plt.ylabel('Average Waiting Time (Minutes)', fontsize=12)
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
